# %%
# %sql

-- TAMAÑO DEL DATASET 
                                                
SELECT COUNT(*) as total_registros
FROM wine_catalog.bronze.products;

# %%
# %sql
    
-- ESTRUCTURA DEL DATASET

DESCRIBE TABLE wine_catalog.bronze.products;

# %%
# %sql

-- MUESTRA DE DATOS

SELECT 
    pais,
    moneda,
    id,
    titulo,
    bodega,
    tipo,
    tags,
    precio,
    precio_tachado,
    stock,
    publicado,
    descripcion,
    _rescued_data
FROM wine_catalog.bronze.products
LIMIT 10;

# %%
# %sql
-- DISTRIBUCIÓN DE VALORES NULOS EN ATRIBUTOS
-- Se utiliza la función RLIKE para filtrar los ID corruptos

WITH total AS (
    SELECT COUNT(*) as total 
    FROM wine_catalog.bronze.products
    where id RLIKE '^[0-9]+$' 
),
nulos AS (
    SELECT
        COUNT(*) - COUNT(id) as nulos_id,
        COUNT(*) - COUNT(titulo) as nulos_titulo,
        COUNT(*) - COUNT(bodega) as nulos_bodega,
        COUNT(*) - COUNT(tipo) as nulos_tipo,
        COUNT(*) - COUNT(tags) as nulos_tags,
        COUNT(*) - COUNT(precio) as nulos_precio,
        COUNT(*) - COUNT(precio_tachado) as nulos_precio_tachado,
        COUNT(*) - COUNT(stock) as nulos_stock,
        COUNT(*) - COUNT(publicado) as nulos_publicado,
        COUNT(*) - COUNT(descripcion) as nulos_descripcion,
        COUNT(*) - COUNT(pais) as nulos_pais,
        COUNT(*) - COUNT(moneda) as nulos_moneda
    FROM wine_catalog.bronze.products
    where id RLIKE '^[0-9]+$'
)
SELECT 
    t.total as total_registros,
    n.*
FROM total t, nulos n;

-- La columna tipo concentra la mayor cantidad de valores nulos con más de mil registros sin clasificar.
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_registros</th><th>nulos_id</th><th>nulos_titulo</th><th>nulos_bodega</th><th>nulos_tipo</th><th>nulos_tags</th><th>nulos_precio</th><th>nulos_precio_tachado</th><th>nulos_stock</th><th>nulos_publicado</th><th>nulos_descripcion</th><th>nulos_pais</th><th>nulos_moneda</th></tr></thead><tbody><tr><td>1894</td><td>0</td><td>0</td><td>0</td><td>1021</td><td>114</td><td>0</td><td>1193</td><td>0</td><td>0</td><td>20</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %sql

-- CANTIDAD DE REGISTROS DUPLICADOS

SELECT
    id,
    COUNT(*) AS repeticiones

FROM wine_catalog.bronze.products
where id RLIKE '^[0-9]+$'
GROUP BY id
HAVING COUNT(*) > 1;
