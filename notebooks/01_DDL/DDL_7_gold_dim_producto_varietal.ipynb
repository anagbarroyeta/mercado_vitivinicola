# %%
# %sql
CREATE TABLE IF NOT EXISTS vitivinicola_catalog.gold.dim_producto_varietal (
    sk_producto BIGINT COMMENT 'Clave subrogada conecta con dim_productos',
    sk_varietal BIGINT COMMENT 'Clave subrogada conecta con dim_varietales'
)
USING DELTA
COMMENT 'Tabla puente para entre productos y varietales';
