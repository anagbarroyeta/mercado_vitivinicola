# %%
# %sql

CREATE TABLE IF NOT EXISTS vitivinicola_catalog.gold.fact_catalogo (
    sk_producto BIGINT,
    sk_tienda BIGINT,
    precio DOUBLE,
    precio_tachado DOUBLE,
    stock BOOLEAN
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Tabla de Hechos de Productos';
