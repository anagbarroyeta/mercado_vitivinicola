# %%
# %sql
-- TABLA SILVER

CREATE TABLE IF NOT EXISTS vitivinicola_catalog.silver.productos (
  id BIGINT,
  titulo STRING,
  bodega STRING,
  tipo STRING,
  tipo_inferido STRING,
  categoria STRING,
  tags STRING,
  precio DOUBLE,
  precio_tachado DOUBLE,
  stock BOOLEAN,
  publicado STRING,
  tienda STRING,
  pais STRING,          
  moneda STRING,
  _ingestion_ts TIMESTAMP,
  _source_file STRING
)
USING DELTA;
