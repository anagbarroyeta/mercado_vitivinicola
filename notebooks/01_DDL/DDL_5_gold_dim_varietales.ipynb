# %%
# %sql

CREATE TABLE IF NOT EXISTS vitivinicola_catalog.gold.dim_varietales (
    sk_varietal BIGINT GENERATED ALWAYS AS IDENTITY,
    varietal STRING COMMENT 'Inferido desde tags'
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Dimensión Varietales';
